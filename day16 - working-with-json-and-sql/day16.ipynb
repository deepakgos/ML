# %%
import pandas as pd

# %% [markdown]
# # Woking with JSON

# %%
pd.read_json('train.json')
# Out:
#           id      cuisine                                        ingredients
# 0      10259        greek  [romaine lettuce, black olives, grape tomatoes...
# 1      25693  southern_us  [plain flour, ground pepper, salt, tomatoes, g...
# 2      20130     filipino  [eggs, pepper, salt, mayonaise, cooking oil, g...
# 3      22213       indian                [water, vegetable oil, wheat, salt]
# 4      13162       indian  [black pepper, shallots, cornflour, cayenne pe...
# ...      ...          ...                                                ...
# 39769  29109        irish  [light brown sugar, granulated sugar, butter, ...
# 39770  11462      italian  [KRAFT Zesty Italian Dressing, purple onion, b...
# 39771   2238        irish  [eggs, citrus fruit, raisins, sourdough starte...
# 39772  41882      chinese  [boneless chicken skinless thigh, minced garli...
# 39773   2362      mexican  [green chile, jalapeno chilies, onions, ground...
#
# [39774 rows x 3 columns]

# %%
pd.read_json('https://api.exchangerate-api.com/v4/latest/INR')
# Out:
#                              provider  \
# AED  https://www.exchangerate-api.com
# AFN  https://www.exchangerate-api.com
# ALL  https://www.exchangerate-api.com
# AMD  https://www.exchangerate-api.com
# ANG  https://www.exchangerate-api.com
# ..                                ...
# XPF  https://www.exchangerate-api.com
# YER  https://www.exchangerate-api.com
# ZAR  https://www.exchangerate-api.com
# ZMW  https://www.exchangerate-api.com
# ZWL  https://www.exchangerate-api.com
#
#                           WARNING_UPGRADE_TO_V6  \
# AED  https://www.exchangerate-api.com/docs/free
# AFN  https://www.exchangerate-api.com/docs/free
# ALL  https://www.exchangerate-api.com/docs/free
# AMD  https://www.exchangerate-api.com/docs/free
# ANG  https://www.exchangerate-api.com/docs/free
# ..                                          ...
# XPF  https://www.exchangerate-api.com/docs/free
# YER  https://www.exchangerate-api.com/docs/free
# ZAR  https://www.exchangerate-api.com/docs/free
# ZMW  https://www.exchangerate-api.com/docs/free
# ZWL  https://www.exchangerate-api.com/docs/free
#
#                                       terms base       date  \
# AED  https://www.exchangerate-api.com/terms  INR 2024-06-19
# AFN  https://www.exchangerate-api.com/terms  INR 2024-06-19
# ALL  https://www.exchangerate-api.com/terms  INR 2024-06-19
# AMD  https://www.exchangerate-api.com/terms  INR 2024-06-19
# ANG  https://www.exchangerate-api.com/terms  INR 2024-06-19
# ..                                      ...  ...        ...
# XPF  https://www.exchangerate-api.com/terms  INR 2024-06-19
# YER  https://www.exchangerate-api.com/terms  INR 2024-06-19
# ZAR  https://www.exchangerate-api.com/terms  INR 2024-06-19
# ZMW  https://www.exchangerate-api.com/terms  INR 2024-06-19
# ZWL  https://www.exchangerate-api.com/terms  INR 2024-06-19
#
#      time_last_updated   rates
# AED         1718755201  0.0440
# AFN         1718755201  0.8470
# ALL         1718755201  1.1200
# AMD         1718755201  4.6600
# ANG         1718755201  0.0215
# ..                 ...     ...
# XPF         1718755201  1.3300
# YER         1718755201  3.0000
# ZAR         1718755201  0.2170
# ZMW         1718755201  0.3110
# ZWL         1718755201  0.1620
#
# [162 rows x 7 columns]

# %% [markdown]
# # Working with SQL

# %%
# !pip install mysql.connector
# !pip install mysql-connector-python
# Out:
# Collecting mysql-connector-python
#   Downloading mysql_connector_python-8.4.0-cp311-cp311-win_amd64.whl.metadata (2.0 kB)
# Downloading mysql_connector_python-8.4.0-cp311-cp311-win_amd64.whl (14.5 MB)
#    ---------------------------------------- 14.5/14.5 MB 557.0 kB/s eta 0:00:00
# Installing collected packages: mysql-connector-python
# Successfully installed mysql-connector-python-8.4.0
# [notice] A new release of pip is available: 23.3 -> 24.0
# [notice] To update, run: python.exe -m pip install --upgrade pip

# %%
import mysql.connector

# %%
# !pip install pandas sqlalchemy mysql-connector-python
# Out:
# Requirement already satisfied: pandas in c:\users\deepak\appdata\local\programs\python\python311\lib\site-packages (2.0.3)
# [notice] A new release of pip is available: 23.3 -> 24.0
# [notice] To update, run: python.exe -m pip install --upgrade pip
# Requirement already satisfied: sqlalchemy in c:\users\deepak\appdata\local\programs\python\python311\lib\site-packages (2.0.19)
# Requirement already satisfied: mysql-connector-python in c:\users\deepak\appdata\local\programs\python\python311\lib\site-packages (8.4.0)
# Requirement already satisfied: python-dateutil>=2.8.2 in c:\users\deepak\appdata\local\programs\python\python311\lib\site-packages (from pandas) (2.8.2)
# Requirement already satisfied: pytz>=2020.1 in c:\users\deepak\appdata\local\programs\python\python311\lib\site-packages (from pandas) (2023.3)
# Requirement already satisfied: tzdata>=2022.1 in c:\users\deepak\appdata\local\programs\python\python311\lib\site-packages (from pandas) (2023.3)
# Requirement already satisfied: numpy>=1.21.0 in c:\users\deepak\appdata\local\programs\python\python311\lib\site-packages (from pandas) (1.25.1)
# Requirement already satisfied: typing-extensions>=4.2.0 in c:\users\deepak\appdata\local\programs\python\python311\lib\site-packages (from sqlalchemy) (4.7.1)
# Requirement already satisfied: greenlet!=0.4.17 in c:\users\deepak\appdata\local\programs\python\python311\lib\site-packages (from sqlalchemy) (2.0.2)
# Requirement already satisfied: six>=1.5 in c:\users\deepak\appdata\local\programs\python\python311\lib\site-packages (from python-dateutil>=2.8.2->pandas) (1.16.0)

# %%
from sqlalchemy import create_engine
import pandas as pd

# %%
# host='localhost'
# user='root'
# password=''
# database='wordpress'
# connection_string = f'mysql+mysqlconnector://{user}:{password}@{host}/{database}'

conn = mysql.connector.connect(
    host='localhost',
    user='root',
    password='',
    database='wordpress'
)
    
cursor = conn.cursor()
cursor.execute("SELECT * FROM wp_actionscheduler_actions")
rows = cursor.fetchall()

# %%
# engine = create_engine(connection_string)
columns = [column[0] for column in cursor.description]

df = pd.DataFrame.from_records(rows, columns=columns)

cursor.close()
conn.close()

# %%
# df = pd.read_sql_query("SELECT * FROM wp_actionscheduler_actions", engine)

# %%
df
# Out:
#     action_id                                       hook    status  \
# 0          64  wpforms_process_entry_emails_meta_cleanup    failed
# 1          65  wpforms_email_summaries_fetch_info_blocks    failed
# 2          67          wpforms_builder_help_cache_update    failed
# 3          68         wpforms_admin_notifications_update    failed
# 4          69  wpforms_email_summaries_fetch_info_blocks    failed
# 5          70  wpforms_email_summaries_fetch_info_blocks    failed
# 6          71         wpforms_admin_notifications_update    failed
# 7          72  wpforms_email_summaries_fetch_info_blocks    failed
# 8          73  wpforms_email_summaries_fetch_info_blocks    failed
# 9          74  wpforms_email_summaries_fetch_info_blocks    failed
# 10         75  wpforms_email_summaries_fetch_info_blocks    failed
# 11         76         wpforms_admin_notifications_update    failed
# 12         77  wpforms_email_summaries_fetch_info_blocks    failed
# 13         78         wpforms_admin_notifications_update    failed
# 14         79  wpforms_email_summaries_fetch_info_blocks    failed
# 15         80  wpforms_email_summaries_fetch_info_blocks    failed
# 16         81         wpforms_admin_notifications_update    failed
# 17         82         wpforms_admin_notifications_update    failed
# 18         84         wpforms_admin_notifications_update    failed
# 19         85         wpforms_admin_notifications_update    failed
# 20         86         wpforms_admin_notifications_update    failed
# 21         87         wpforms_admin_notifications_update    failed
# 22         88         wpforms_admin_notifications_update    failed
# 23         89         wpforms_admin_notifications_update    failed
# 24         90         wpforms_admin_notifications_update    failed
# 25         91         wpforms_admin_notifications_update    failed
# 26         92         wpforms_admin_notifications_update    failed
# 27         93         wpforms_admin_notifications_update    failed
# 28         94         wpforms_admin_notifications_update    failed
# 29         95         wpforms_admin_notifications_update    failed
# 30         96         wpforms_admin_notifications_update    failed
# 31         97         wpforms_admin_notifications_update    failed
# 32         98         wpforms_admin_notifications_update    failed
# 33         99         wpforms_admin_notifications_update    failed
# 34        100         wpforms_admin_notifications_update    failed
# 35        101         wpforms_admin_notifications_update    failed
# 36        102  wpforms_process_entry_emails_meta_cleanup    failed
# 37        103  wpforms_email_summaries_fetch_info_blocks    failed
# 38        104  wpforms_process_entry_emails_meta_cleanup    failed
# 39        105          wpforms_admin_addons_cache_update  complete
# 40        106  wpforms_email_summaries_fetch_info_blocks    failed
# 41        107  wpforms_email_summaries_fetch_info_blocks    failed
# 42        108  wpforms_email_summaries_fetch_info_blocks   pending
# 43        109  wpforms_process_entry_emails_meta_cleanup   pending
# 44        110          wpforms_admin_addons_cache_update   pending
#
#     scheduled_date_gmt scheduled_date_local                    args  \
# 0  2021-05-24 00:00:00  2021-05-24 00:00:00     {"tasks_meta_id":1}
# 1  2021-05-19 22:03:15  2021-05-19 22:03:15  {"tasks_meta_id":null}
# 2  2021-05-30 11:03:20  2021-05-30 11:03:20     {"tasks_meta_id":3}
# 3                  NaT                  NaT     {"tasks_meta_id":4}
# 4  2021-05-18 03:23:09  2021-05-18 03:23:09  {"tasks_meta_id":null}
# 5  2021-05-18 16:06:16  2021-05-18 16:06:16  {"tasks_meta_id":null}
# 6                  NaT                  NaT     {"tasks_meta_id":5}
# 7  2021-05-21 07:50:16  2021-05-21 07:50:16  {"tasks_meta_id":null}
# 8  2021-05-19 12:18:16  2021-05-19 12:18:16  {"tasks_meta_id":null}
# 9  2021-05-21 21:14:19  2021-05-21 21:14:19  {"tasks_meta_id":null}
# 10 2021-05-21 00:43:42  2021-05-21 00:43:42  {"tasks_meta_id":null}
# 11                 NaT                  NaT     {"tasks_meta_id":6}
# 12 2021-05-21 07:56:20  2021-05-21 07:56:20  {"tasks_meta_id":null}
# 13                 NaT                  NaT     {"tasks_meta_id":7}
# 14 2021-05-20 06:17:23  2021-05-20 06:17:23  {"tasks_meta_id":null}
# 15 2021-05-24 03:52:58  2021-05-24 03:52:58  {"tasks_meta_id":null}
# 16                 NaT                  NaT     {"tasks_meta_id":8}
# 17                 NaT                  NaT     {"tasks_meta_id":9}
# 18                 NaT                  NaT    {"tasks_meta_id":10}
# 19                 NaT                  NaT    {"tasks_meta_id":11}
# 20                 NaT                  NaT    {"tasks_meta_id":12}
# 21                 NaT                  NaT    {"tasks_meta_id":13}
# 22                 NaT                  NaT    {"tasks_meta_id":14}
# 23                 NaT                  NaT    {"tasks_meta_id":15}
# 24                 NaT                  NaT    {"tasks_meta_id":16}
# 25                 NaT                  NaT    {"tasks_meta_id":17}
# 26                 NaT                  NaT    {"tasks_meta_id":18}
# 27                 NaT                  NaT    {"tasks_meta_id":19}
# 28                 NaT                  NaT    {"tasks_meta_id":20}
# 29                 NaT                  NaT    {"tasks_meta_id":21}
# 30                 NaT                  NaT    {"tasks_meta_id":22}
# 31                 NaT                  NaT    {"tasks_meta_id":23}
# 32                 NaT                  NaT    {"tasks_meta_id":24}
# 33                 NaT                  NaT    {"tasks_meta_id":25}
# 34                 NaT                  NaT    {"tasks_meta_id":26}
# 35                 NaT                  NaT    {"tasks_meta_id":27}
# 36 2021-05-25 00:00:00  2021-05-25 00:00:00    {"tasks_meta_id":28}
# 37 2021-05-18 14:09:50  2021-05-18 14:09:50  {"tasks_meta_id":null}
# 38 2022-07-03 00:00:00  2022-07-03 00:00:00    {"tasks_meta_id":29}
# 39 2022-07-09 06:51:49  2022-07-09 06:51:49     {"tasks_meta_id":2}
# 40 2022-06-28 16:54:18  2022-06-28 16:54:18  {"tasks_meta_id":null}
# 41 2022-06-29 17:12:20  2022-06-29 17:12:20  {"tasks_meta_id":null}
# 42 2022-07-04 05:58:27  2022-07-04 05:58:27  {"tasks_meta_id":null}
# 43 2022-09-09 00:00:00  2022-09-09 00:00:00    {"tasks_meta_id":30}
# 44 2022-09-15 08:46:24  2022-09-15 08:46:24     {"tasks_meta_id":2}
#
#                                              schedule  group_id  attempts  \
# 0   O:32:"ActionScheduler_IntervalSchedule":5:{s:2...         2         1
# 1   O:32:"ActionScheduler_IntervalSchedule":5:{s:2...         2         1
# 2   O:32:"ActionScheduler_IntervalSchedule":5:{s:2...         2         1
# 3            O:28:"ActionScheduler_NullSchedule":0:{}         2         1
# 4   O:32:"ActionScheduler_IntervalSchedule":5:{s:2...         2         1
# 5   O:32:"ActionScheduler_IntervalSchedule":5:{s:2...         2         1
# 6            O:28:"ActionScheduler_NullSchedule":0:{}         2         1
# 7   O:32:"ActionScheduler_IntervalSchedule":5:{s:2...         2         1
# 8   O:32:"ActionScheduler_IntervalSchedule":5:{s:2...         2         1
# 9   O:32:"ActionScheduler_IntervalSchedule":5:{s:2...         2         1
# 10  O:32:"ActionScheduler_IntervalSchedule":5:{s:2...         2         1
# 11           O:28:"ActionScheduler_NullSchedule":0:{}         2         1
# 12  O:32:"ActionScheduler_IntervalSchedule":5:{s:2...         2         1
# 13           O:28:"ActionScheduler_NullSchedule":0:{}         2         1
# 14  O:32:"ActionScheduler_IntervalSchedule":5:{s:2...         2         1
# 15  O:32:"ActionScheduler_IntervalSchedule":5:{s:2...         2         1
# 16           O:28:"ActionScheduler_NullSchedule":0:{}         2         1
# 17           O:28:"ActionScheduler_NullSchedule":0:{}         2         1
# 18           O:28:"ActionScheduler_NullSchedule":0:{}         2         1
# 19           O:28:"ActionScheduler_NullSchedule":0:{}         2         1
# 20           O:28:"ActionScheduler_NullSchedule":0:{}         2         1
# 21           O:28:"ActionScheduler_NullSchedule":0:{}         2         1
# 22           O:28:"ActionScheduler_NullSchedule":0:{}         2         1
# 23           O:28:"ActionScheduler_NullSchedule":0:{}         2         1
# 24           O:28:"ActionScheduler_NullSchedule":0:{}         2         1
# 25           O:28:"ActionScheduler_NullSchedule":0:{}         2         1
# 26           O:28:"ActionScheduler_NullSchedule":0:{}         2         1
# 27           O:28:"ActionScheduler_NullSchedule":0:{}         2         1
# 28           O:28:"ActionScheduler_NullSchedule":0:{}         2         1
# 29           O:28:"ActionScheduler_NullSchedule":0:{}         2         1
# 30           O:28:"ActionScheduler_NullSchedule":0:{}         2         1
# 31           O:28:"ActionScheduler_NullSchedule":0:{}         2         1
# 32           O:28:"ActionScheduler_NullSchedule":0:{}         2         1
# 33           O:28:"ActionScheduler_NullSchedule":0:{}         2         1
# 34           O:28:"ActionScheduler_NullSchedule":0:{}         2         1
# 35           O:28:"ActionScheduler_NullSchedule":0:{}         2         1
# 36  O:32:"ActionScheduler_IntervalSchedule":5:{s:2...         2         1
# 37  O:32:"ActionScheduler_IntervalSchedule":5:{s:2...         2         1
# 38  O:32:"ActionScheduler_IntervalSchedule":5:{s:2...         2         1
# 39  O:32:"ActionScheduler_IntervalSchedule":5:{s:2...         2         1
# 40  O:32:"ActionScheduler_IntervalSchedule":5:{s:2...         2         1
# 41  O:32:"ActionScheduler_IntervalSchedule":5:{s:2...         2         1
# 42  O:32:"ActionScheduler_IntervalSchedule":5:{s:2...         2         0
# 43  O:32:"ActionScheduler_IntervalSchedule":5:{s:2...         2         0
# 44  O:32:"ActionScheduler_IntervalSchedule":5:{s:2...         2         0
#
#       last_attempt_gmt  last_attempt_local  claim_id extended_args
# 0  2021-05-24 05:33:28 2021-05-24 05:33:28         0          None
# 1  2021-05-23 11:04:23 2021-05-23 11:04:23         0          None
# 2  2022-07-02 06:51:49 2022-07-02 06:51:49         0          None
# 3  2021-05-23 11:04:24 2021-05-23 11:04:24         0          None
